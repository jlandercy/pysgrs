# %%
import pysgrs
import warnings
warnings.simplefilter("ignore")

# %%
[c for c in dir(pysgrs) if c.endswith("Cypher") and not c.startswith("Generic")]
# Out:
# ['AffineCypher',
#  'Base16Cypher',
#  'Base32Cypher',
#  'Base64Cypher',
#  'Base85Cypher',
#  'CaesarCypher',
#  'HexadecimalCypher',
#  'PermutationCypher',
#  'PipelineCypher',
#  'ReversedCypher',
#  'RotationCypher',
#  'TranspositionCypher',
#  'URLQuoteCypher',
#  'VigenereCypher']

# %%
s = "A successful man is one who can lay a firm foundation with the bricks others have thrown at him."

# %%
C = pysgrs.CaesarCypher()
C.cypher(s)
# Out:
# 'D vxffhvvixo pdq lv rqh zkr fdq odb d ilup irxqgdwlrq zlwk wkh eulfnv rwkhuv kdyh wkurzq dw klp.'

# %%
C.to_graph()

# %%
C = pysgrs.VigenereCypher(key="David Brinkley".upper().replace(" ", ""))
C.cypher(s)
# Out:
# 'D spkffjasew qyq in wqf npb mlr jdy v nlsd nbeyhywijv zjkp grp fplcfa ruymec seth tczrxe ig rtq.'

# %%
C.to_graph()

# %%
A = pysgrs.GenericIntegerAlphabet("ABCDEFG")
print(A)
# Out:
# <GenericIntegerAlphabet size=7 symbols='ABCDEFG'>

# %%
C = pysgrs.CaesarCypher(alphabet=A)
print(C)
# Out:
# <CaesarCypher alphabet=<GenericIntegerAlphabet size=7 symbols='ABCDEFG'>>

# %%
C.to_graph()

# %%
C.cypher("Aba Fegha")
# Out:
# 'Ded Bachd'
